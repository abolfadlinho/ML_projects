# %% [markdown]
# # Importing Needed Libraries

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

import keras
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.layers import Dense, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## Reading The Data

# %%
data_dir = '/kaggle/input/tesla-stock-data-updated-till-28jun2021/TSLA.csv'
df = pd.read_csv(data_dir, parse_dates= True , index_col= "Date")

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#                  Open   High        Low      Close  Adj Close    Volume
# Date
# 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2010-07-01  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 2010-07-02  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 2010-07-06  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2416 entries, 2010-06-29 to 2020-02-03
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2416 non-null   float64
#  1   High       2416 non-null   float64
#  2   Low        2416 non-null   float64
#  3   Close      2416 non-null   float64
#  4   Adj Close  2416 non-null   float64
#  5   Volume     2416 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 132.1 KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2416.000000  2416.000000  2416.000000  2416.000000  2416.000000
# mean    186.271147   189.578224   182.916639   186.403651   186.403651
# std     118.740163   120.892329   116.857591   119.136020   119.136020
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      34.342498    34.897501    33.587501    34.400002    34.400002
# 50%     213.035004   216.745002   208.870002   212.960007   212.960007
# 75%     266.450012   270.927513   262.102501   266.774994   266.774994
# max     673.690002   786.140015   673.520020   780.000000   780.000000
#
#              Volume
# count  2.416000e+03
# mean   5.572722e+06
# std    4.987809e+06
# min    1.185000e+05
# 25%    1.899275e+06
# 50%    4.578400e+06
# 75%    7.361150e+06
# max    4.706500e+07

# %%
plt.figure(figsize=(15, 6))
df['Open'].plot()
df['Close'].plot()
plt.ylabel(None)
plt.xlabel(None)
plt.title("Opening & Closing Price of Tesla")
plt.legend(['Open Price', 'Close Price'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 6))
df['Volume'].plot()
plt.ylabel('Volume')
plt.xlabel(None)
plt.title("Sales Volume of Tesla")
plt.tight_layout()
plt.show()

# %%
# We'll use pct_change to find the percent change for each day
plt.figure(figsize=(15, 6))
df['Adj Close'].pct_change().hist(bins=50)
plt.ylabel('Daily Return')
plt.title(f'Tesla Dialy Return')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Choosing Prediction Column

# %%
dataset = df["Close"]
dataset = pd.DataFrame(dataset)

data = dataset.values

data.shape
# Out:
# (2416, 1)

# %% [markdown]
# ### Normalizing Data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range= (0, 1))
scaled_data = scaler.fit_transform(np.array(data).reshape(-1, 1))

# %% [markdown]
# ### Splitting the Data

# %%
# 75% to Train , 25% to Test
train_size = int(len(data)*.75)
test_size = len(data) - train_size

print("Train Size :",train_size,"Test Size :",test_size)

train_data = scaled_data[ :train_size , 0:1 ]
test_data = scaled_data[ train_size-60: , 0:1 ]
# Out:
# Train Size : 1812 Test Size : 604

# %%
train_data.shape, test_data.shape
# Out:
# ((1812, 1), (664, 1))

# %% [markdown]
# ### Creating training set

# %%
# Creating a Training set with 60 time-steps and 1 output
x_train = []
y_train = []

for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
# Convert to numpy array
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshaping the input
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
x_train.shape , y_train.shape
# Out:
# ((1752, 60, 1), (1752,))

# %% [markdown]
# # LSTM Model

# %% [markdown]
# ### Model Dtructure

# %%
model = Sequential([
    LSTM(50, return_sequences= True, input_shape= (x_train.shape[1], 1)),
    LSTM(64, return_sequences= False),
    Dense(32),
    Dense(16),
    Dense(1)
])

model.compile(optimizer= 'adam', loss= 'mse' , metrics= "mean_absolute_error")

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            10400
#
#  lstm_1 (LSTM)               (None, 64)                29440
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 42,465
# Trainable params: 42,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Training

# %%
# Fitting the LSTM to the Training set
callbacks = [EarlyStopping(monitor= 'loss', patience= 10 , restore_best_weights= True)]
history = model.fit(x_train, y_train, epochs= 100, batch_size= 32 , callbacks= callbacks )
# Out:
# Epoch 1/100
# 55/55 [==============================] - 6s 8ms/step - loss: 0.0022 - mean_absolute_error: 0.0280
# Epoch 2/100
# 55/55 [==============================] - 0s 8ms/step - loss: 2.3922e-04 - mean_absolute_error: 0.0106
# Epoch 3/100
# 55/55 [==============================] - 0s 8ms/step - loss: 2.1407e-04 - mean_absolute_error: 0.0104
# Epoch 4/100
# 55/55 [==============================] - 0s 8ms/step - loss: 2.2310e-04 - mean_absolute_error: 0.0106
# Epoch 5/100
# 55/55 [==============================] - 0s 8ms/step - loss: 2.2201e-04 - mean_absolute_error: 0.0108
# Epoch 6/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.7166e-04 - mean_absolute_error: 0.0092
# Epoch 7/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.5198e-04 - mean_absolute_error: 0.0085
# Epoch 8/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.7666e-04 - mean_absolute_error: 0.0093
# Epoch 9/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.4459e-04 - mean_absolute_error: 0.0084
# Epoch 10/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.4235e-04 - mean_absolute_error: 0.0083
# Epoch 11/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.3647e-04 - mean_absolute_error: 0.0083
# Epoch 12/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.2285e-04 - mean_absolute_error: 0.0077
# Epoch 13/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.3706e-04 - mean_absolute_error: 0.0081
# Epoch 14/100
# 55/55 [==============================] - 1s 10ms/step - loss: 1.5009e-04 - mean_absolute_error: 0.0086
# Epoch 15/100
# 55/55 [==============================] - 1s 10ms/step - loss: 1.1596e-04 - mean_absolute_error: 0.0075
# Epoch 16/100
# 55/55 [==============================] - 0s 9ms/step - loss: 1.1594e-04 - mean_absolute_error: 0.0075
# Epoch 17/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.1529e-04 - mean_absolute_error: 0.0076
# Epoch 18/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.1169e-04 - mean_absolute_error: 0.0075
# Epoch 19/100
# 55/55 [==============================] - 0s 8ms/step - loss: 9.8833e-05 - mean_absolute_error: 0.0067
# Epoch 20/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.0326e-04 - mean_absolute_error: 0.0070
# Epoch 21/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.0627e-04 - mean_absolute_error: 0.0072
# Epoch 22/100
# 55/55 [==============================] - 1s 10ms/step - loss: 1.2424e-04 - mean_absolute_error: 0.0078
# Epoch 23/100
# 55/55 [==============================] - 0s 9ms/step - loss: 8.9921e-05 - mean_absolute_error: 0.0065
# Epoch 24/100
# 55/55 [==============================] - 0s 8ms/step - loss: 1.0491e-04 - mean_absolute_error: 0.0071
# Epoch 25/100
# 55/55 [==============================] - 0s 8ms/step - loss: 9.7685e-05 - mean_absolute_error: 0.0070
# Epoch 26/100
# 55/55 [==============================] - 0s 8ms/step - loss: 8.1994e-05 - mean_absolute_error: 0.0061
# Epoch 27/100
# 55/55 [==============================] - 0s 8ms/step - loss: 8.9875e-05 - mean_absolute_error: 0.0067
# Epoch 28/100
# 55/55 [==============================] - 0s 8ms/step - loss: 9.3440e-05 - mean_absolute_error: 0.0066
# Epoch 29/100
# 55/55 [==============================] - 0s 8ms/step - loss: 8.3262e-05 - mean_absolute_error: 0.0063
# Epoch 30/100
# 55/55 [==============================] - 0s 8ms/step - loss: 8.0131e-05 - mean_absolute_error: 0.0064
# Epoch 31/100
# 55/55 [==============================] - 0s 8ms/step - loss: 7.6717e-05 - mean_absolute_error: 0.0061
# Epoch 32/100
# 55/55 [==============================] - 0s 8ms/step - loss: 7.1196e-05 - mean_absolute_error: 0.0057
# Epoch 33/100
# 55/55 [==============================] - 0s 8ms/step - loss: 7.9834e-05 - mean_absolute_error: 0.0062
# Epoch 34/100
# 55/55 [==============================] - 0s 8ms/step - loss: 8.1349e-05 - mean_absolute_error: 0.0064
# Epoch 35/100
# 55/55 [==============================] - 0s 8ms/step - loss: 8.3268e-05 - mean_absolute_error: 0.0065
# Epoch 36/100
# 55/55 [==============================] - 0s 8ms/step - loss: 7.0022e-05 - mean_absolute_error: 0.0058
# Epoch 37/100
# 55/55 [==============================] - 0s 8ms/step - loss: 6.9524e-05 - mean_absolute_error: 0.0056
# Epoch 38/100
# 55/55 [==============================] - 0s 8ms/step - loss: 6.1899e-05 - mean_absolute_error: 0.0053
# Epoch 39/100
# 55/55 [==============================] - 0s 8ms/step - loss: 6.6699e-05 - mean_absolute_error: 0.0057
# Epoch 40/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.8953e-05 - mean_absolute_error: 0.0051
# Epoch 41/100
# 55/55 [==============================] - 0s 8ms/step - loss: 6.9447e-05 - mean_absolute_error: 0.0058
# Epoch 42/100
# 55/55 [==============================] - 0s 8ms/step - loss: 6.3959e-05 - mean_absolute_error: 0.0055
# Epoch 43/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.6583e-05 - mean_absolute_error: 0.0050
# Epoch 44/100
# 55/55 [==============================] - 0s 8ms/step - loss: 6.3223e-05 - mean_absolute_error: 0.0055
# Epoch 45/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.8402e-05 - mean_absolute_error: 0.0052
# Epoch 46/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.9937e-05 - mean_absolute_error: 0.0054
# Epoch 47/100
# 55/55 [==============================] - 1s 10ms/step - loss: 5.4010e-05 - mean_absolute_error: 0.0051
# Epoch 48/100
# 55/55 [==============================] - 0s 9ms/step - loss: 5.8534e-05 - mean_absolute_error: 0.0055
# Epoch 49/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.3941e-05 - mean_absolute_error: 0.0050
# Epoch 50/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.7141e-05 - mean_absolute_error: 0.0052
# Epoch 51/100
# 55/55 [==============================] - 0s 8ms/step - loss: 6.8473e-05 - mean_absolute_error: 0.0057
# Epoch 52/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.7330e-05 - mean_absolute_error: 0.0052
# Epoch 53/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.3063e-05 - mean_absolute_error: 0.0050
# Epoch 54/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.9944e-05 - mean_absolute_error: 0.0056
# Epoch 55/100
# 55/55 [==============================] - 0s 8ms/step - loss: 6.6231e-05 - mean_absolute_error: 0.0059
# Epoch 56/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.6972e-05 - mean_absolute_error: 0.0054
# Epoch 57/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.9765e-05 - mean_absolute_error: 0.0049
# Epoch 58/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.9406e-05 - mean_absolute_error: 0.0056
# Epoch 59/100
# 55/55 [==============================] - 0s 8ms/step - loss: 6.9064e-05 - mean_absolute_error: 0.0062
# Epoch 60/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.7100e-05 - mean_absolute_error: 0.0047
# Epoch 61/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.8904e-05 - mean_absolute_error: 0.0048
# Epoch 62/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.7957e-05 - mean_absolute_error: 0.0048
# Epoch 63/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.5868e-05 - mean_absolute_error: 0.0046
# Epoch 64/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.5114e-05 - mean_absolute_error: 0.0046
# Epoch 65/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.4328e-05 - mean_absolute_error: 0.0046
# Epoch 66/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.9082e-05 - mean_absolute_error: 0.0048
# Epoch 67/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.9760e-05 - mean_absolute_error: 0.0049
# Epoch 68/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.8691e-05 - mean_absolute_error: 0.0049
# Epoch 69/100
# 55/55 [==============================] - 0s 8ms/step - loss: 6.3801e-05 - mean_absolute_error: 0.0056
# Epoch 70/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.6918e-05 - mean_absolute_error: 0.0048
# Epoch 71/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.8938e-05 - mean_absolute_error: 0.0047
# Epoch 72/100
# 55/55 [==============================] - 1s 10ms/step - loss: 4.9176e-05 - mean_absolute_error: 0.0050
# Epoch 73/100
# 55/55 [==============================] - 0s 9ms/step - loss: 4.3522e-05 - mean_absolute_error: 0.0044
# Epoch 74/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.4928e-05 - mean_absolute_error: 0.0045
# Epoch 75/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.3180e-05 - mean_absolute_error: 0.0044
# Epoch 76/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.5489e-05 - mean_absolute_error: 0.0052
# Epoch 77/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.6728e-05 - mean_absolute_error: 0.0053
# Epoch 78/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.3148e-05 - mean_absolute_error: 0.0044
# Epoch 79/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.4329e-05 - mean_absolute_error: 0.0046
# Epoch 80/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.6984e-05 - mean_absolute_error: 0.0048
# Epoch 81/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.8781e-05 - mean_absolute_error: 0.0048
# Epoch 82/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.3832e-05 - mean_absolute_error: 0.0053
# Epoch 83/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.0409e-05 - mean_absolute_error: 0.0052
# Epoch 84/100
# 55/55 [==============================] - 0s 8ms/step - loss: 4.8790e-05 - mean_absolute_error: 0.0049
# Epoch 85/100
# 55/55 [==============================] - 1s 9ms/step - loss: 4.4662e-05 - mean_absolute_error: 0.0046
# Epoch 86/100
# 55/55 [==============================] - 1s 11ms/step - loss: 5.6412e-05 - mean_absolute_error: 0.0054
# Epoch 87/100
# 55/55 [==============================] - 1s 10ms/step - loss: 5.8033e-05 - mean_absolute_error: 0.0053
# Epoch 88/100
# 55/55 [==============================] - 0s 8ms/step - loss: 5.4822e-05 - mean_absolute_error: 0.0053

# %% [markdown]
# ### Model Evaluation

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["mean_absolute_error"])
plt.legend(['Mean Squared Error','Mean Absolute Error'])
plt.title("Losses")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# # Predection

# %% [markdown]
# ### Creating testing set

# %%
# Creating a testing set with 60 time-steps and 1 output
x_test = []
y_test = []

for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# %%
x_test.shape , y_test.shape
# Out:
# ((604, 60, 1), (604,))

# %%
#inverse y_test scaling
predictions = model.predict(x_test)

#inverse predictions scaling
predictions = scaler.inverse_transform(predictions)
predictions.shape
# Out:
# 19/19 [==============================] - 1s 3ms/step
# (604, 1)

# %% [markdown]
# ### Root mean square error

# %%
#inverse y_test scaling
y_test = scaler.inverse_transform([y_test])

RMSE = np.sqrt(np.mean( y_test - predictions )**2).round(2)
RMSE
# Out:
# 5.4

# %% [markdown]
# ### Visualize Predictions with The Data

# %%
train = dataset.iloc[:train_size , 0:1]
test = dataset.iloc[train_size: , 0:1]
test['Predictions'] = predictions

plt.figure(figsize= (16, 6))
plt.title('Tesla Close Stock Price Prediction', fontsize= 18)
plt.xlabel('Date', fontsize= 18)
plt.ylabel('Close Price', fontsize= 18)
plt.plot(train['Close'], linewidth= 3)
plt.plot(test['Close'], linewidth= 3)
plt.plot(test["Predictions"], linewidth= 3)
plt.legend(['Train', 'Test', 'Predictions'])

# %% [markdown]
# # Forecast Next 30 Days

# %%
from datetime import timedelta

# %%
def insert_end(Xin, new_input):
    timestep = 60
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future = 30
forcast = []
Xin = x_test[-1 :, :, :]
time = []
for i in range(0, future):
    out = model.predict(Xin, batch_size=5)
    forcast.append(out[0, 0]) 
    print(forcast)
    Xin = insert_end(Xin, out[0, 0]) 
    time.append(pd.to_datetime(df.index[-1]) + timedelta(days=i))
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [0.8277545]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593]
# 1/1 [==============================] - 0s 16ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887]
# 1/1 [==============================] - 0s 16ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967]
# 1/1 [==============================] - 0s 20ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703, 0.993768]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703, 0.993768, 0.9999756]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703, 0.993768, 0.9999756, 1.0059967]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703, 0.993768, 0.9999756, 1.0059967, 1.0118352]
# 1/1 [==============================] - 0s 20ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703, 0.993768, 0.9999756, 1.0059967, 1.0118352, 1.0174959]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703, 0.993768, 0.9999756, 1.0059967, 1.0118352, 1.0174959, 1.0229838]
# 1/1 [==============================] - 0s 17ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703, 0.993768, 0.9999756, 1.0059967, 1.0118352, 1.0174959, 1.0229838, 1.0283029]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703, 0.993768, 0.9999756, 1.0059967, 1.0118352, 1.0174959, 1.0229838, 1.0283029, 1.0334569]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703, 0.993768, 0.9999756, 1.0059967, 1.0118352, 1.0174959, 1.0229838, 1.0283029, 1.0334569, 1.0384486]
# 1/1 [==============================] - 0s 18ms/step
# [0.8277545, 0.82787657, 0.83397084, 0.8447809, 0.8577671, 0.8707134, 0.8824593, 0.8928279, 0.90218264, 0.9109879, 0.91955775, 0.9280035, 0.9363005, 0.94437957, 0.9521887, 0.95971364, 0.96696967, 0.97398335, 0.98077834, 0.9873703, 0.993768, 0.9999756, 1.0059967, 1.0118352, 1.0174959, 1.0229838, 1.0283029, 1.0334569, 1.0384486, 1.0432806]

# %%
time
# Out:
# [Timestamp('2020-02-03 00:00:00'),
#  Timestamp('2020-02-04 00:00:00'),
#  Timestamp('2020-02-05 00:00:00'),
#  Timestamp('2020-02-06 00:00:00'),
#  Timestamp('2020-02-07 00:00:00'),
#  Timestamp('2020-02-08 00:00:00'),
#  Timestamp('2020-02-09 00:00:00'),
#  Timestamp('2020-02-10 00:00:00'),
#  Timestamp('2020-02-11 00:00:00'),
#  Timestamp('2020-02-12 00:00:00'),
#  Timestamp('2020-02-13 00:00:00'),
#  Timestamp('2020-02-14 00:00:00'),
#  Timestamp('2020-02-15 00:00:00'),
#  Timestamp('2020-02-16 00:00:00'),
#  Timestamp('2020-02-17 00:00:00'),
#  Timestamp('2020-02-18 00:00:00'),
#  Timestamp('2020-02-19 00:00:00'),
#  Timestamp('2020-02-20 00:00:00'),
#  Timestamp('2020-02-21 00:00:00'),
#  Timestamp('2020-02-22 00:00:00'),
#  Timestamp('2020-02-23 00:00:00'),
#  Timestamp('2020-02-24 00:00:00'),
#  Timestamp('2020-02-25 00:00:00'),
#  Timestamp('2020-02-26 00:00:00'),
#  Timestamp('2020-02-27 00:00:00'),
#  Timestamp('2020-02-28 00:00:00'),
#  Timestamp('2020-02-29 00:00:00'),
#  Timestamp('2020-03-01 00:00:00'),
#  Timestamp('2020-03-02 00:00:00'),
#  Timestamp('2020-03-03 00:00:00')]

# %% [markdown]
# ### Create forecasted dataframe

# %%
forcasted_output = np.asanyarray(forcast)   
forcasted_output = forcasted_output.reshape(-1, 1) 
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", "Forecasted"

# %% [markdown]
# ## Forecasted tesla close price

# %%
df_result
# Out:
#          Date  Forecasted
# 0  2020-02-03  648.369995
# 1  2020-02-04  648.463318
# 2  2020-02-05  653.120544
# 3  2020-02-06  661.381592
# 4  2020-02-07  671.305664
# 5  2020-02-08  681.199219
# 6  2020-02-09  690.175415
# 7  2020-02-10  698.099121
# 8  2020-02-11  705.247986
# 9  2020-02-12  711.976990
# 10 2020-02-13  718.526062
# 11 2020-02-14  724.980286
# 12 2020-02-15  731.320862
# 13 2020-02-16  737.494873
# 14 2020-02-17  743.462585
# 15 2020-02-18  749.213196
# 16 2020-02-19  754.758240
# 17 2020-02-20  760.118103
# 18 2020-02-21  765.310791
# 19 2020-02-22  770.348389
# 20 2020-02-23  775.237488
# 21 2020-02-24  779.981384
# 22 2020-02-25  784.582642
# 23 2020-02-26  789.044434
# 24 2020-02-27  793.370300
# 25 2020-02-28  797.564209
# 26 2020-02-29  801.629028
# 27 2020-03-01  805.567749
# 28 2020-03-02  809.382385
# 29 2020-03-03  813.075012

# %%
plt.figure(figsize=(16, 8))
plt.title('Tesla Close Stock Price Forecasting For Next 30 Days')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close' ,fontsize=18)
plt.plot(df['Close'])
plt.plot(df_result.set_index('Date')[['Forecasted']])
